# %%
import pydot
from collections import defaultdict 
from IPython.display import Image, display
from itertools import permutations

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])

# %%
def pancakePn(d,a,b):
  count = 0
  while True:
    for i in d:
      if(a in d[i]):
        count = count + 1
        a = i
    if(a == b):
      break
  return count

# %%
def convert(list): 
      
    # Converting integer list to string list 
    s = [str(i) for i in list] 
      
    # Join list items using join() 
    res = int("".join(s))

    return res

# %%
def pancakePns(s):
    a = []
    p = list(range(1, s+1))
    s1 = str(convert(p))
    x = permutations(p)
    for j in list(x):
        j = list(j)
        s2 = str(convert(j))
        a.append(pancakePn(ModifiedBFS2(j), s1, s2))
    return max(a)

# %%
def ModifiedBFS(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="graph", strict = True)
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydot.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                    node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
              
          
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
                else:
                    edge = pydot.Edge(lstr(s),lstr(d))
                    G.add_edge(edge)
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)
        return graph

# %%
def ModifiedBFS2(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        #G = pydot.Dot(graph_type="graph", strict = True)
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            #node = pydot.Node(lstr(s))
            #G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
              
          
                  #G.add_node(node)
                  #edge = pydot.Edge(lstr(s),lstr(d))
                  #G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        return graph

# %% [markdown]
# 1. PLOTEAR NETWORK DE PANQUEQUES Y CALCULAR PN PARA N PEQUEÑOS

# %%
i = 1
while i <= 5:
  a = list(range(1, i+1))
  b = permutations(a)
  b = list(b)
  b = b[0]
  ModifiedBFS(b)
  i = i + 1

# %%
n = 1
for i in range(5):
  print(pancakePns(n))
  n = n + 1
# Out:
# 0
# 1
# 3
# 4
# 5

# %% [markdown]
# 2. CORRER EL CODIGO POR 8 HORAS

# %%
n = 1
while True:
  print(pancakePns(n))
  n = n + 1
# Out:
# 0
# 1
# 3
# 4
# 5
# 7
# 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-183-f8a34c7128fc> in <module>()
#       1 n = 1
#       2 while True:
# ----> 3   print(pancakePns(n))
#       4   n = n + 1
#
# <ipython-input-154-7773e7e924f2> in pancakePns(s)
#       7         j = list(j)
#       8         s2 = str(convert(j))
# ----> 9         a.append(pancakePn(ModifiedBFS2(j), s1, s2))
#      10     return max(a)
#
# <ipython-input-122-ddbc8d452641> in ModifiedBFS2(s)
#      28               for i in range(len(s)-1):
#      29                 d = s[i+1::-1] + s[i+2:]
# ---> 30                 if (d != s) and not(lstr(d) in visited.keys()):
#      31
#      32
#
# <ipython-input-2-86c2ac92c70d> in lstr(p)
#       1 def lstr(p):
# ----> 2         return ''.join([str(elem)  for elem in p])
#
# <ipython-input-2-86c2ac92c70d> in <listcomp>(.0)
#       1 def lstr(p):
# ----> 2         return ''.join([str(elem)  for elem in p])
#
# KeyboardInterrupt:

# %% [markdown]
# 3. PLOTEAR ARBOL CON DOBLE ESPATULA

# %%
def ModifiedBFS3(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydot.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for j in range(len(s)):
                for i in range(len(s)-j-1):
                  st = s[j:]
                  d = s[:j] + st[i+1::-1] + st[i+2:]  
                  if (d != s) and not(lstr(d) in visited.keys()):
                  
                    if(d != sorted(d)):
                      node = pydot.Node(lstr(d))
                    else:
                      node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                    
                    G.add_node(node)
                    edge = pydot.Edge(lstr(s),lstr(d))
                    G.add_edge(edge)
                    graph[lstr(s)].append(lstr(d))
                    queue.append(d) 
                    visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
ModifiedBFS3([5,2,3,4,1])
